# %%
import pandas as pd

# %%
df = pd.read_csv("DATA/DATA1/CmptData.csv")

# %%
df
# Out:
#    # Department/Fixture Compatibility              Unnamed: 1  \
# 0                     # Department ID  Department Description
# 1                                3301            Smoke Buster
# 2                                3302              Foot Needs
# 3                                3315                Elastics
# 4                                3325            Incontinence
# 5                                3330                 Eye Ear
# 6                                3352             Pill Minder
# 7                                3353                Vitamins
# 8                                3364              Pediatrics
# 9                                3365           Convalescence
# 10                               3366        Antacid Laxative
# 11                               3367              Cough Cold
# 12                               3368   Diet Sports Nutrition
# 13                               3369               First Aid
# ...
